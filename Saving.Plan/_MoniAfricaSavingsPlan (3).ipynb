# %% [markdown]
# ## DATA INSIGHT PRODUCTION DATA OF USERS' SAVINGS PLAN

# %%
import pandas as pd

# %%
SavingsPlan = pd.read_csv('transactions.csv')

# %%
SavingsPlan.head()    # the first 5 transaction savings plan
# Out:
#    id account_number           company transaction_date payment_type  \
# 0   1     account_63           MetLife   1/13/2023 0:02       Credit
# 1   2    account_267             FedEx  1/15/2023 17:00      Invoice
# 2   3    account_458     Cisco Systems   1/8/2023 20:02      Invoice
# 3   4    account_991           Dropbox   1/30/2023 8:23       Credit
# 4   5    account_241  General Electric   1/21/2023 0:16      Invoice
#
#          plan
# 0         Pro
# 1       Basic
# 2         Pro
# 3       Basic
# 4  Enterprise

# %%
SavingsPlan.tail()  # the least  5 transaction savings plan
# Out:
#     id account_number           company transaction_date payment_type  \
# 45  46    account_248             Front   1/26/2023 0:27      Invoice
# 46  47    account_453  Costco Wholesale   1/1/2023 19:12        Debit
# 47  48    account_280       Walt Disney   1/5/2023 20:06      Invoice
# 48  49    account_885            Oracle    1/4/2023 4:46       Credit
# 49  50    account_713        Salesforce   1/11/2023 4:36       Credit
#
#           plan
# 45         Pro
# 46  Enterprise
# 47         Pro
# 48       Basic
# 49  Enterprise

# %%
SavingsPlan.info()     #  overall information on transaction savings plan data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   account_number    50 non-null     object
#  2   company           50 non-null     object
#  3   transaction_date  50 non-null     object
#  4   payment_type      50 non-null     object
#  5   plan              50 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.5+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns      #data visualisation show below

# %%
sns.displot(SavingsPlan['plan'])

# %%
sns.displot(SavingsPlan['payment_type'])

# %%
sns.stripplot(x="payment_type",y="company",data=SavingsPlan)
# Out:
# <Axes: xlabel='payment_type', ylabel='company'>

# %%
SavingsPlan
# Out:
#     id account_number                company transaction_date payment_type  \
# 0    1     account_63                MetLife   1/13/2023 0:02       Credit
# 1    2    account_267                  FedEx  1/15/2023 17:00      Invoice
# 2    3    account_458          Cisco Systems   1/8/2023 20:02      Invoice
# 3    4    account_991                Dropbox   1/30/2023 8:23       Credit
# 4    5    account_241       General Electric   1/21/2023 0:16      Invoice
# 5    6    account_682                   Gong   1/2/2023 16:02        Debit
# 6    7    account_175                 Stripe    1/6/2023 5:01      Invoice
# 7    8    account_676             Home Depot    1/5/2023 8:25       Credit
# 8    9    account_615    Goldman Sachs Group    1/7/2023 2:07       Credit
# 9   10     account_69       Procter & Gamble   1/21/2023 0:58      Invoice
# 10  11    account_945            Progressive   1/18/2023 7:26      Invoice
# ...

# %%
import sqlite3

# %%
 conn = sqlite3.connect('transaction.db') # sql database created
  
conn.execute('CREATE TABLE IF NOT EXISTS transactiondata ({}) ' .format( ' , '.join(SavingsPlan.columns)))

# %%
SavingsPlan.shape
# Out:
# (50, 6)

# %%
Transaction = pd.read_sql_query('SELECT * from transactiondata',conn)

# %%
Transaction
# Out:
# Empty DataFrame
# Columns: [id, account_number, company, transaction_date, payment_type, plan]
# Index: []

# %%
import sqlite3
from sqlalchemy import create_engine

# %%
saveplan =create_engine('sqlite://' ,echo=False)
SavingsPlan.to_sql('plan',saveplan, if_exists='replace',index=false)
usersplan =saveplan.execute

# %%
# Thank you!
